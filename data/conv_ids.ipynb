# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# lancer le conc=vertisseur de tokens en IDS

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls /content/drive/MyDrive/
# Out:
# 'Colab Notebooks'   dataset-IDs.txt	  modele_streaming.py
#  con_tok_rh.py	    dataset_token.txt	  projets
#  dataset_ids.txt    modele_streaming.pt   vocab_l.json

# %%
# !python /content/drive/MyDrive/con_tok_rh.py
# Out:
# debut
# lancement de la lecture
# lire 1000 lignes de /content/drive/MyDrive/dataset_token.txt
# chunk traité de 1000 lignes
