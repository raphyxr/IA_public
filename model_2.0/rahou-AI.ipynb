# %% [markdown]
# ### remonter au drive :

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/Othercomputers/surface 9/python/projets/IA
# Out:
# /content/drive/Othercomputers/surface 9/python/projets/IA

# %% [markdown]
# ### verification de la presence des fichiers :

# %%
# !ls "/content/drive/Othercomputers/surface 9/python/projets/IA"
# Out:
# calc_erreurs.py  dev	      model		   to_do.md
# conv.py		 essai.ipynb  modele_streaming.pt  vocab_clean.json
# data		 idea	      modele_streaming.py  vocab.json
# dataset_ids.txt  image.png    rahou-AI.ipynb
# dataset-i.txt	 logs	      session.py

# %% [markdown]
# ### lancement du code :

# %%
# !python modele_streaming.py --epochs 20
# Out:
# debut
# nouveau datset
# dataset trouve: /content/drive/Othercomputers/surface 9/python/projets/IA/dataset-i.txt (1049176251 octets)
# dataset utilise: /content/drive/Othercomputers/surface 9/python/projets/IA/dataset-i.txt
# vocab.json invalide: /content/drive/Othercomputers/surface 9/python/projets/IA/vocab.json ligne 2536675, colonne 14 (position 57227814). Decodage texte desactive.
# Regenerer ou recopier vocab.json, puis verifier le fichier avec: python -m json.tool vocab.json
# vocab introuvable: /content/drive/Othercomputers/surface 9/python/projets/IA/vocab.json (decodage texte desactive)
# essai de chargement
# checkpoint charge: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# debut epoch 1
# epoch 1 | chunk 1 [##############################] 2496/2496 (100.0%) loss=18.7888
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 1 | chunk 2 [##############################] 2496/2496 (100.0%) loss=4.24093
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 1 | chunk 3 [##############################] 2496/2496 (100.0%) loss=17.9947
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 1 | chunk 4 [##############################] 2496/2496 (100.0%) loss=14.2422
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 1 | chunk 5 [##############################] 2496/2496 (100.0%) loss=13.1696
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 1 | chunk 6 [##############################] 2496/2496 (100.0%) loss=10.1921
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 1 | chunk 7 [##############################] 2496/2496 (100.0%) loss=8.65117
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 1 | chunk 8 [##############################] 2496/2496 (100.0%) loss=5.11461
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 1 | chunk 9 [##############################] 2496/2496 (100.0%) loss=9.41437
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 1 | chunk 10 [##############################] 2496/2496 (100.0%) loss=7.27157
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 1 | chunk 11 [##############################] 2496/2496 (100.0%) loss=6.11423
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 1 | chunk 12 [##############################] 2496/2496 (100.0%) loss=7.90267
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 1 | chunk 13 [##############################] 2496/2496 (100.0%) loss=7.08586
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 1 | chunk 14 [##############################] 2496/2496 (100.0%) loss=10.4682
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 1 | chunk 15 [##############################] 2496/2496 (100.0%) loss=5.43879
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 1 | chunk 16 [##############################] 2496/2496 (100.0%) loss=11.9093
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 1 | chunk 17 [##############################] 2496/2496 (100.0%) loss=11.8510
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 1 | chunk 18 [##############################] 2496/2496 (100.0%) loss=11.0323
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 1 | chunk 19 [##############################] 2496/2496 (100.0%) loss=5.20075
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 1 | chunk 20 [##############################] 2496/2496 (100.0%) loss=12.4558
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 1 | chunk 21 [##############################] 76/76 (100.0%) loss=8.97947
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 1 loss: 10.180266563190546
# fin 1
# debut epoch 2
# epoch 2 | chunk 1 [##############################] 2496/2496 (100.0%) loss=9.31294
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 2 | chunk 2 [##############################] 2496/2496 (100.0%) loss=11.5237
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 2 | chunk 3 [##############################] 2496/2496 (100.0%) loss=10.4588
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 2 | chunk 4 [##############################] 2496/2496 (100.0%) loss=3.77852
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 2 | chunk 5 [##############################] 2496/2496 (100.0%) loss=6.40413
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 2 | chunk 6 [##############################] 2496/2496 (100.0%) loss=10.6514
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 2 | chunk 7 [##############################] 2496/2496 (100.0%) loss=7.97531
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 2 | chunk 8 [##############################] 2496/2496 (100.0%) loss=5.38057
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 2 | chunk 9 [##############################] 2496/2496 (100.0%) loss=11.4730
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 2 | chunk 10 [##############################] 2496/2496 (100.0%) loss=5.64750
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 2 | chunk 11 [##############################] 2496/2496 (100.0%) loss=5.55611
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 2 | chunk 12 [##############################] 2496/2496 (100.0%) loss=11.8672
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 2 | chunk 13 [##############################] 2496/2496 (100.0%) loss=4.24740
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 2 | chunk 14 [##############################] 2496/2496 (100.0%) loss=10.1925
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 2 | chunk 15 [##############################] 2496/2496 (100.0%) loss=7.27112
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 2 | chunk 16 [##############################] 2496/2496 (100.0%) loss=9.11953
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 2 | chunk 17 [##############################] 2496/2496 (100.0%) loss=6.80536
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 2 | chunk 18 [##############################] 2496/2496 (100.0%) loss=5.51714
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 2 | chunk 19 [##############################] 2496/2496 (100.0%) loss=7.42606
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 2 | chunk 20 [##############################] 2496/2496 (100.0%) loss=7.70390
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 2 | chunk 21 [##############################] 76/76 (100.0%) loss=9.01826
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 2 loss: 7.892404963765408
# fin 1
# debut epoch 3
# epoch 3 | chunk 1 [##############################] 2496/2496 (100.0%) loss=11.1153
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 3 | chunk 2 [##############################] 2496/2496 (100.0%) loss=10.8824
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 3 | chunk 3 [##############################] 2496/2496 (100.0%) loss=6.53054
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 3 | chunk 4 [##############################] 2496/2496 (100.0%) loss=7.76378
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 3 | chunk 5 [##############################] 2496/2496 (100.0%) loss=7.71172
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 3 | chunk 6 [##############################] 2496/2496 (100.0%) loss=3.29592
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 3 | chunk 7 [##############################] 2496/2496 (100.0%) loss=6.47987
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 3 | chunk 8 [##############################] 2496/2496 (100.0%) loss=4.29582
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 3 | chunk 9 [##############################] 2496/2496 (100.0%) loss=3.39162
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 3 | chunk 10 [##############################] 2496/2496 (100.0%) loss=11.2409
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 3 | chunk 11 [##############################] 2496/2496 (100.0%) loss=10.5261
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 3 | chunk 12 [##############################] 2496/2496 (100.0%) loss=12.0357
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 3 | chunk 13 [##############################] 2496/2496 (100.0%) loss=8.69995
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 3 | chunk 14 [##############################] 2496/2496 (100.0%) loss=5.81492
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 3 | chunk 15 [##############################] 2496/2496 (100.0%) loss=8.29942
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 3 | chunk 16 [##############################] 2496/2496 (100.0%) loss=10.4751
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 3 | chunk 17 [##############################] 2496/2496 (100.0%) loss=5.37933
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 3 | chunk 18 [##############################] 2496/2496 (100.0%) loss=4.80026
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 3 | chunk 19 [##############################] 2496/2496 (100.0%) loss=7.09234
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 3 | chunk 20 [##############################] 2496/2496 (100.0%) loss=8.84835
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 3 | chunk 21 [##############################] 76/76 (100.0%) loss=9.00297
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 3 loss: 7.389630103856802
# fin 1
# debut epoch 4
# epoch 4 | chunk 1 [##############################] 2496/2496 (100.0%) loss=7.34287
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 4 | chunk 2 [##############################] 2496/2496 (100.0%) loss=7.97265
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 4 | chunk 3 [##############################] 2496/2496 (100.0%) loss=4.43507
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 4 | chunk 4 [##############################] 2496/2496 (100.0%) loss=6.11782
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 4 | chunk 5 [##############################] 2496/2496 (100.0%) loss=8.64862
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 4 | chunk 6 [##############################] 2496/2496 (100.0%) loss=4.91578
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 4 | chunk 7 [##############################] 2496/2496 (100.0%) loss=6.35765
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 4 | chunk 8 [##############################] 2496/2496 (100.0%) loss=7.78802
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 4 | chunk 9 [##############################] 2496/2496 (100.0%) loss=7.13618
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 4 | chunk 10 [##############################] 2496/2496 (100.0%) loss=9.16872
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 4 | chunk 11 [##############################] 2496/2496 (100.0%) loss=4.21563
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 4 | chunk 12 [##############################] 2496/2496 (100.0%) loss=9.29885
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 4 | chunk 13 [##############################] 2496/2496 (100.0%) loss=7.31848
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 4 | chunk 14 [##############################] 2496/2496 (100.0%) loss=5.14409
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 4 | chunk 15 [##############################] 2496/2496 (100.0%) loss=8.83693
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 4 | chunk 16 [##############################] 2496/2496 (100.0%) loss=7.73765
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 4 | chunk 17 [##############################] 2496/2496 (100.0%) loss=5.29966
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 4 | chunk 18 [##############################] 2496/2496 (100.0%) loss=6.44951
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 4 | chunk 19 [##############################] 2496/2496 (100.0%) loss=9.58330
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 4 | chunk 20 [##############################] 2496/2496 (100.0%) loss=9.43230
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 4 | chunk 21 [##############################] 76/76 (100.0%) loss=5.53811
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 4 loss: 7.028810770934055
# fin 1
# debut epoch 5
# epoch 5 | chunk 1 [##############################] 2496/2496 (100.0%) loss=4.56581
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 5 | chunk 2 [##############################] 2496/2496 (100.0%) loss=5.85148
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 5 | chunk 3 [##############################] 2496/2496 (100.0%) loss=9.99162
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 5 | chunk 4 [##############################] 2496/2496 (100.0%) loss=6.49517
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 5 | chunk 5 [##############################] 2496/2496 (100.0%) loss=4.33498
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 5 | chunk 6 [##############################] 2496/2496 (100.0%) loss=3.91100
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 5 | chunk 7 [##############################] 2496/2496 (100.0%) loss=7.82271
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 5 | chunk 8 [##############################] 2496/2496 (100.0%) loss=8.87824
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 5 | chunk 9 [##############################] 2496/2496 (100.0%) loss=7.21053
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 5 | chunk 10 [##############################] 2496/2496 (100.0%) loss=2.24454
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 5 | chunk 11 [##############################] 2496/2496 (100.0%) loss=6.95425
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 5 | chunk 12 [##############################] 2496/2496 (100.0%) loss=7.26009
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 5 | chunk 13 [##############################] 2496/2496 (100.0%) loss=4.97866
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 5 | chunk 14 [##############################] 2496/2496 (100.0%) loss=4.51050
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 5 | chunk 15 [##############################] 2496/2496 (100.0%) loss=9.67321
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 5 | chunk 16 [##############################] 2496/2496 (100.0%) loss=7.95546
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 5 | chunk 17 [##############################] 2496/2496 (100.0%) loss=8.69337
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 5 | chunk 18 [##############################] 2496/2496 (100.0%) loss=7.68641
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 5 | chunk 19 [##############################] 2496/2496 (100.0%) loss=9.46049
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 5 | chunk 20 [##############################] 2496/2496 (100.0%) loss=8.70617
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 5 | chunk 21 [##############################] 76/76 (100.0%) loss=9.08591
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 5 loss: 6.725169603385676
# fin 1
# debut epoch 6
# epoch 6 | chunk 1 [##############################] 2496/2496 (100.0%) loss=6.58741
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 6 | chunk 2 [##############################] 2496/2496 (100.0%) loss=2.93654
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 6 | chunk 3 [##############################] 2496/2496 (100.0%) loss=9.14431
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 6 | chunk 4 [##############################] 2496/2496 (100.0%) loss=7.08374
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 6 | chunk 5 [##############################] 2496/2496 (100.0%) loss=6.39074
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 6 | chunk 6 [##############################] 2496/2496 (100.0%) loss=3.25362
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 6 | chunk 7 [##############################] 2496/2496 (100.0%) loss=4.04904
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 6 | chunk 8 [##############################] 2496/2496 (100.0%) loss=1.86277
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 6 | chunk 9 [##############################] 2496/2496 (100.0%) loss=6.98863
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 6 | chunk 10 [##############################] 2496/2496 (100.0%) loss=7.32250
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 6 | chunk 11 [##############################] 2496/2496 (100.0%) loss=7.17240
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 6 | chunk 12 [##############################] 2496/2496 (100.0%) loss=6.16713
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 6 | chunk 13 [##############################] 2496/2496 (100.0%) loss=8.22969
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 6 | chunk 14 [##############################] 2496/2496 (100.0%) loss=10.1252
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 6 | chunk 15 [##############################] 2496/2496 (100.0%) loss=2.83695
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 6 | chunk 16 [##############################] 2496/2496 (100.0%) loss=7.22540
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 6 | chunk 17 [##############################] 2496/2496 (100.0%) loss=5.36815
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 6 | chunk 18 [##############################] 2496/2496 (100.0%) loss=8.10653
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 6 | chunk 19 [##############################] 2496/2496 (100.0%) loss=11.0911
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 6 | chunk 20 [##############################] 2496/2496 (100.0%) loss=5.93461
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 6 | chunk 21 [##############################] 76/76 (100.0%) loss=5.43646
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 6 loss: 6.45865447480577
# fin 1
# debut epoch 7
# epoch 7 | chunk 1 [##############################] 2496/2496 (100.0%) loss=3.83938
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 7 | chunk 2 [##############################] 2496/2496 (100.0%) loss=3.43689
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 7 | chunk 3 [##############################] 2496/2496 (100.0%) loss=5.44670
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 7 | chunk 4 [##############################] 2496/2496 (100.0%) loss=7.12839
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 7 | chunk 5 [##############################] 2496/2496 (100.0%) loss=9.45717
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 7 | chunk 6 [##############################] 2496/2496 (100.0%) loss=6.08592
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 7 | chunk 7 [##############################] 2496/2496 (100.0%) loss=4.99136
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 7 | chunk 8 [##############################] 2496/2496 (100.0%) loss=2.81304
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 7 | chunk 9 [##############################] 2496/2496 (100.0%) loss=7.44452
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 7 | chunk 10 [##############################] 2496/2496 (100.0%) loss=6.62291
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 7 | chunk 11 [##############################] 2496/2496 (100.0%) loss=6.30681
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 7 | chunk 12 [##############################] 2496/2496 (100.0%) loss=5.26679
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 7 | chunk 13 [##############################] 2496/2496 (100.0%) loss=8.10410
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 7 | chunk 14 [##############################] 2496/2496 (100.0%) loss=2.18451
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 7 | chunk 15 [##############################] 2496/2496 (100.0%) loss=7.85122
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 7 | chunk 16 [##############################] 2496/2496 (100.0%) loss=7.37117
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 7 | chunk 17 [##############################] 2496/2496 (100.0%) loss=7.55660
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 7 | chunk 18 [##############################] 2496/2496 (100.0%) loss=4.20452
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 7 | chunk 19 [##############################] 2496/2496 (100.0%) loss=3.51892
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 7 | chunk 20 [##############################] 2496/2496 (100.0%) loss=2.16730
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 7 | chunk 21 [##############################] 76/76 (100.0%) loss=8.83057
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 7 loss: 6.206276129059498
# fin 1
# debut epoch 8
# epoch 8 | chunk 1 [##############################] 2496/2496 (100.0%) loss=3.73236
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 1 traite, tokens vus: 5000
# epoch 8 | chunk 2 [##############################] 2496/2496 (100.0%) loss=6.63296
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 2 traite, tokens vus: 9992
# epoch 8 | chunk 3 [##############################] 2496/2496 (100.0%) loss=7.31218
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 3 traite, tokens vus: 14984
# epoch 8 | chunk 4 [##############################] 2496/2496 (100.0%) loss=7.57549
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 4 traite, tokens vus: 19976
# epoch 8 | chunk 5 [##############################] 2496/2496 (100.0%) loss=6.81890
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 5 traite, tokens vus: 24968
# epoch 8 | chunk 6 [##############################] 2496/2496 (100.0%) loss=7.06287
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 6 traite, tokens vus: 29960
# epoch 8 | chunk 7 [##############################] 2496/2496 (100.0%) loss=2.54462
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 7 traite, tokens vus: 34952
# epoch 8 | chunk 8 [##############################] 2496/2496 (100.0%) loss=3.81011
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 8 traite, tokens vus: 39944
# epoch 8 | chunk 9 [##############################] 2496/2496 (100.0%) loss=4.32057
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 9 traite, tokens vus: 44936
# epoch 8 | chunk 10 [##############################] 2496/2496 (100.0%) loss=4.90224
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 10 traite, tokens vus: 49928
# epoch 8 | chunk 11 [##############################] 2496/2496 (100.0%) loss=5.70381
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 11 traite, tokens vus: 54920
# epoch 8 | chunk 12 [##############################] 2496/2496 (100.0%) loss=6.00699
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 12 traite, tokens vus: 59912
# epoch 8 | chunk 13 [##############################] 2496/2496 (100.0%) loss=6.27960
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 13 traite, tokens vus: 64904
# epoch 8 | chunk 14 [##############################] 2496/2496 (100.0%) loss=3.46258
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 14 traite, tokens vus: 69896
# epoch 8 | chunk 15 [##############################] 2496/2496 (100.0%) loss=6.29998
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 15 traite, tokens vus: 74888
# epoch 8 | chunk 16 [##############################] 2496/2496 (100.0%) loss=4.86764
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 16 traite, tokens vus: 79880
# epoch 8 | chunk 17 [##############################] 2496/2496 (100.0%) loss=4.70785
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 17 traite, tokens vus: 84872
# epoch 8 | chunk 18 [##############################] 2496/2496 (100.0%) loss=3.86654
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 18 traite, tokens vus: 89864
# epoch 8 | chunk 19 [##############################] 2496/2496 (100.0%) loss=3.16773
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 19 traite, tokens vus: 94856
# epoch 8 | chunk 20 [##############################] 2496/2496 (100.0%) loss=7.13975
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# chunk 20 traite, tokens vus: 99848
# epoch 8 | chunk 21 [##############################] 76/76 (100.0%) loss=6.85917
# checkpoint sauvegarde: /content/drive/Othercomputers/surface 9/python/projets/IA/modele_streaming.pt
# epoch 8 loss: 5.977433011817258
# fin 1
# debut epoch 9
# epoch 9 | chunk 1 [#############-----------------] 1144/2496 ( 45.8%) loss=4.16757
