# %% [markdown]
# ### remonter au drive :

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/Othercomputers/surface 9/python/projets/IA
# Out:
# /content/drive/Othercomputers/surface 9/python/projets/IA

# %% [markdown]
# ### verification de la presence des fichiers :

# %%
# !ls "/content/drive/Othercomputers/surface 9/python/projets/IA"
# Out:
#  Agent		   dev	     'model 2.0'	      __pycache__
#  bak		   idea      'model 2.1'	      rahou-AI.ipynb
#  data		   logs      'model 3'		      to_do.md
#  dataset_ids.txt   logs.txt   model_streaming_v3.py   vocab.json
#  dataset-i.txt	  'model 1'   modelV3.0.pt

# %% [markdown]
# ### lancement du code :

# %%
# !python model_streaming_v3.py --epochs 20
# Out:
# debut
# nouveau datset
# nouveau model 3.1
# transformeurs corrigé
# dataset trouve: /content/drive/Othercomputers/surface 9/python/projets/IA/dataset_ids.txt (938657462 octets)
# dataset utilise: /content/drive/Othercomputers/surface 9/python/projets/IA/dataset_ids.txt
# vocab.json invalide: /content/drive/Othercomputers/surface 9/python/projets/IA/vocab.json ligne 2536675, colonne 14 (position 57227814). Decodage texte desactive.
# Regenerer ou recopier vocab.json, puis verifier le fichier avec: python -m json.tool vocab.json
# vocab introuvable: /content/drive/Othercomputers/surface 9/python/projets/IA/vocab.json (decodage texte desactive)
# device utilise: cuda
# cuda disponible: True
# gpu: Tesla T4
# cuda version pytorch: 12.8
# nombre de gpu detectes: 1
# essai de chargement
# checkpoint charge: /content/drive/Othercomputers/surface 9/python/projets/IA/modelV3.0.pt
# debut epoch 1
# epoch 1 | chunk 1 [##############################] 1242/1242 (100.0%) loss=6.2055
# ...

# %%
# !nvidia-smi -l 1  # Affiche l'utilisation du GPU en temps réel
